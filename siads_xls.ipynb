# %%
import pandas as pd
import openpyxl

all_sheets = pd.read_excel('cafi-SIADS_RelatorioBalancoFisicoFinanceiro.xls', engine='calamine', sheet_name=[2])

siads_xls = pd.concat(all_sheets.values(), ignore_index=True)
# infos = siads_xls[['Unnamed: 1', 'Unnamed: 8']]
# infos = infos.drop_duplicates()
# infos.to_clipboard()
# display(infos)
# siads_xls = pd.DataFrame()
# siads_xls.to_clipboard(index=False)

# %%
siads_xls = siads_xls[['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5','Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',  'Unnamed: 12']]
siads_xls = siads_xls.drop_duplicates()
siads_xls.to_clipboard(index=False)
display(siads_xls)
# Out:
#                              Unnamed: 1  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 6                                   NaN
# 9                                 CONTA
# 12     115610100 - MATERIAIS DE CONSUMO
# 15  14 - MATERIAL EDUCATIVO E ESPORTIVO
# 17                                  NaN
# 19                                  NaN
# 21                                  NaN
# 22                                  NaN
# 24                                  NaN
# 28                                  NaN
# 29                                  NaN
# 31                                  NaN
# 35                                  NaN
# 36                                  NaN
# 38                                  NaN
# 42                                  NaN
# 43                                  NaN
# 45                                  NaN
# 50                                  NaN
# ...
